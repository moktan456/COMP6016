# %% [markdown]
# <a href="https://colab.research.google.com/github/moktan456/Data-Mining/blob/main/Answers_04_AssociationPatternMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supermarket basket association pattern mining
#
# In this question, we perform association pattern mining using the supermarket dataset `supermarket.arff` from the [Weka MOOC](https://www.cs.waikato.ac.nz/ml/weka/courses.html).
#
#
# 1. Load the data file `supermarket.arff` into a pandas data frame
#
# 2. Remove the following attributes
#   - `department*`
#   - `non host support`
#   - `total`
#
# 3.  Select the Apriori algorithm and perform frequent itemset mining with minsup = 0.2 and minconf = 0.8 and find out:
#   - The numbers of frequent 2-itemsets, and 3-itemsets.
#   - The best three (2) rules with largest confidence. Examine these rules and describe them in your own words.
#
# 4. The supermarket manager wishes to boost the sale of fruit and therefore the manager needs to know other itemsets most likely be purchased with fruit to make promotion decisions.
#   - Using the same minimum support and minimum confidence value.
#   - List the top three itemsets to report to the supermarket manager.
#
# 5. Repeat task 3, but using the FP Growth algorithm instead.
#   - Compare the rules found.
#   - Are they consistent?

# %% [markdown]
# ## 0 Upgrade mlxtend
# The default version of `mlxtend` on Google Colaborate is too old for this prac
# so we must upgrade it. We want something that is at least version 0.18.
# Note that code statements beginning with `!` are not python code, but system calls. If you are running this in a personal jupyterlab you might have to update this module a different way.

# %%
! pip install --upgrade 'mlxtend>=0.18'
# Out:
# Requirement already satisfied: mlxtend>=0.18 in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (1.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend>=0.18) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend>=0.18) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend>=0.18) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend>=0.18) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend>=0.18) (1.16.0)

# %%
# Check we have the right version
import mlxtend
print(mlxtend.__version__)
# Out:
# 0.22.0

# %% [markdown]
# If you ran the two cells above inreverse order then you'll have to restart the kernel before you can load the newer version of the `mlxtend` module.
#
# To do this: choose "Runitime" -> "Restart runtime".

# %%
import pandas as pd
from scipy.io import arff
import urllib
import urllib.request
import numpy as np

# %% [markdown]
# ## 1 Load the data file `supermarket.arff` into a pandas data frame
#
# We did this in a previous prac: download the file into your working directory using `urrlib`, load it using `scipy`, and then convert to a `pandas` data frame. The file on the Weka website has a few problems that we need to work around, so I've provided a cleaned version of the data on [GitHub](https://raw.githubusercontent.com/PaulHancock/COMP5009_pracs/main/data/supermarket.arff).

# %%
data_url = 'https://raw.githubusercontent.com/PaulHancock/COMP5009_pracs/main/data/supermarket.arff'
file_name = 'supermarket.arff'
urllib.request.urlretrieve(data_url, file_name)
# Out:
# ('supermarket.arff', <http.client.HTTPMessage at 0x7a8075074850>)

# %%
# load the data from arff format
data = arff.loadarff('supermarket.arff')
raw_df = pd.DataFrame(data[0])
# The data table is 1 and 0, but we want it to be boolean (true/false) so we
# need to convert from int -> bool
df = raw_df.astype(bool)

# %%
df.describe()
# Out:
#        department1 department2 department3 department4 department5  \
# count         4627        4627        4627        4627        4627
# unique           2           2           2           2           2
# top          False       False       False       False       False
# freq          3580        4496        4537        4543        4452
#
#        department6 department7 department8 department9 grocery misc  ...  \
# count         4627        4627        4627        4627         4627  ...
# unique           2           2           1           2            2  ...
# top          False       False       False       False        False  ...
# freq          4625        4560        4627        4545         4449  ...
#
#        department208 department209 department210 department211 department212  \
# count           4627          4627          4627          4627          4627
# unique             1             1             2             2             2
# top            False         False         False         False         False
# freq            4627          4627          4436          4420          4589
#
#        department213 department214 department215 department216 total
# count           4627          4627          4627          4627  4627
# unique             2             1             1             1     1
# top            False         False         False         False  True
# freq            4605          4627          4627          4627  4627
#
# [4 rows x 217 columns]

# %% [markdown]
# ## 2 Remove attributes
# Remove the following attributes as they have been deemed to be not-useful:
#   - `department*`
#   - `non host support`
#   - `total`

# %%
cols_to_drop = ['non host support', 'total']
# Instead of hand writing all the names that start with department, use a loop
for col in df.columns:
  if col.startswith('department'): # choose all the columns which start with the word 'department'
    cols_to_drop.append(col)
print("The folloiwing columns will be dropped:")
print(cols_to_drop)
# Out:
# The folloiwing columns will be dropped:
# ['non host support', 'total', 'department1', 'department2', 'department3', 'department4', 'department5', 'department6', 'department7', 'department8', 'department9', 'department11', 'department57', 'department70', 'department79', 'department80', 'department81', 'department88', 'department89', 'department98', 'department100', 'department101', 'department102', 'department107', 'department108', 'department109', 'department110', 'department111', 'department112', 'department113', 'department114', 'department116', 'department117', 'department118', 'department119', 'department120', 'department122', 'department123', 'department124', 'department125', 'department126', 'department127', 'department128', 'department129', 'department130', 'department137', 'department138', 'department139', 'department140', 'department141', 'department142', 'department143', 'department144', 'department145', 'department146', 'department147', 'department148', 'department149', 'department150', 'department151', 'department152', 'department153', 'department154', 'department155', 'department156', 'department157', 'department158', 'department159', 'department160', 'department161', 'department162', 'department163', 'department164', 'department165', 'department166', 'department167', 'department168', 'department169', 'department170', 'department171', 'department172', 'department173', 'department174', 'department175', 'department176', 'department177', 'department178', 'department179', 'department189', 'department192', 'department193', 'department194', 'department195', 'department196', 'department197', 'department198', 'department199', 'department201', 'department202', 'department203', 'department204', 'department205', 'department206', 'department207', 'department208', 'department209', 'department210', 'department211', 'department212', 'department213', 'department214', 'department215', 'department216']

# %%
df = df.drop(columns=cols_to_drop)

# %%
# confirm we have dropped the columns by showing a summary, we should have 104 cols left, all with descriptive names.
df.describe()
# Out:
#        grocery misc baby needs bread and cake baking needs coupons  \
# count          4627       4627           4627         4627    4627
# unique            2          2              2            2       1
# top           False      False           True         True   False
# freq           4449       4008           3330         2795    4627
#
#        juice-sat-cord-ms    tea biscuits canned fish-meat canned fruit  ...  \
# count               4627   4627     4627             4627         4627  ...
# unique                 2      2        2                2            2  ...
# top                 True  False     True            False        False  ...
# freq                2463   3731     2605             3686         3344  ...
#
#        casks red wine 750ml white nz 750ml red nz 750ml white imp  \
# count            4627           4627         4627            4627
# unique              2              2            2               2
# top             False          False        False           False
# freq             4576           4346         4536            4528
#
#        750ml red imp sparkling nz sparkling imp brew kits/accesry  \
# count           4627         4627          4627              4627
# unique             2            2             2                 1
# top            False        False         False             False
# freq            4530         4498          4604              4627
#
#        port and sherry ctrled label wine
# count             4627              4627
# unique               2                 1
# top              False             False
# freq              4602              4627
#
# [4 rows x 104 columns]

# %% [markdown]
# ## 3 Select the Apriori algorithm
#
# Select the Apriori algorithm and perform frequent itemset mining with `minsup = 0.2` and `minconf = 0.8` and find out:
#
# - The numbers of frequent 2-itemsets, and 3-itemsets.
# - The best three rules with largest confidence. Examine these rules and describe them in your own words.

# %% [markdown]
# The `apriori` algorithm is found in the `mlxtend` package, so we import it along with the `association_rules` function.

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
ap_itemsets = apriori(df,
                      min_support=0.2,  # choose the (relative) minsup
                      use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ap_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                                           itemsets
# 0    0.719689                                   (bread and cake)
# 1    0.604063                                     (baking needs)
# 2    0.532310                                (juice-sat-cord-ms)
# 3    0.563000                                         (biscuits)
# 4    0.203372                                 (canned fish-meat)
# ..        ...                                                ...
# 541  0.224552        (fruit, biscuits, vegetables, frozen foods)
# 542  0.219365          (fruit, biscuits, milk-cream, vegetables)
# 543  0.228442      (fruit, vegetables, milk-cream, frozen foods)
# 544  0.202939  (milk-cream, baking needs, bread and cake, veg...
# 545  0.200778  (bread and cake, frozen foods, vegetables, fru...
#
# [546 rows x 2 columns]

# %% [markdown]
# Now that we have our itemsets we want to chose those with `2<=k<=3`.
# This isn't explicitly stored within our dataframe so we'll make a new column which is just the value of `len(itemsets)`.

# %%
def find_k(row):
  """Return the number of items in the itemset"""
  return len(row['itemsets'])

# Create a new column which counts the number of items in the itemset
ap_itemsets['k'] = ap_itemsets.apply(find_k, # Apply the function `find_k`
                                     axis=1) # apply the function to each row
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ap_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                                           itemsets  k
# 0    0.719689                                   (bread and cake)  1
# 1    0.604063                                     (baking needs)  1
# 2    0.532310                                (juice-sat-cord-ms)  1
# 3    0.563000                                         (biscuits)  1
# 4    0.203372                                 (canned fish-meat)  1
# ..        ...                                                ... ..
# 541  0.224552        (fruit, biscuits, vegetables, frozen foods)  4
# 542  0.219365          (fruit, biscuits, milk-cream, vegetables)  4
# 543  0.228442      (fruit, vegetables, milk-cream, frozen foods)  4
# 544  0.202939  (milk-cream, baking needs, bread and cake, veg...  5
# 545  0.200778  (bread and cake, frozen foods, vegetables, fru...  5
#
# [546 rows x 3 columns]

# %%
k2_itemsets = np.sum(ap_itemsets['k'] == 2) # count the number of rows where k=2
k3_itemsets = np.sum(ap_itemsets['k'] == 3) # count the number of rows where k=3
print(f"There are {k2_itemsets} itemsets with k=2")
print(f"There are {k3_itemsets} itemsets with k=3")
# Out:
# There are 182 itemsets with k=2
# There are 252 itemsets with k=3
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Now lets see the top 10 itemsets
# try either .head() or .nlargest(10,'support')
ap_itemsets.nlargest(10, 'support')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                      itemsets  k
# 0   0.719689              (bread and cake)  1
# 28  0.640156                       (fruit)  1
# 29  0.639939                  (vegetables)  1
# 23  0.635185                  (milk-cream)  1
# 1   0.604063                (baking needs)  1
# 12  0.587206                (frozen foods)  1
# 3   0.563000                    (biscuits)  1
# 2   0.532310           (juice-sat-cord-ms)  1
# 51  0.505079  (bread and cake, milk-cream)  2
# 16  0.503566           (party snack foods)  1

# %% [markdown]
# Note that the top 10 itemsets are all 1-itemsets. Is this surprising to you?

# %% [markdown]
# We use these itemsets to generate association rules with a minimum confidence of 0.8.

# %%
ap_rules = association_rules(ap_itemsets,
                             metric='confidence',
                             min_threshold=0.8) # choose the minimum confidence value
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ap_rules.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                 antecedents       consequents  antecedent support  \
# 0            (canned fruit)  (bread and cake)            0.277285
# 1            (jams-spreads)  (bread and cake)            0.276205
# 2               (margarine)  (bread and cake)            0.494489
# 3             (small goods)  (bread and cake)            0.241193
# 4  (biscuits, baking needs)  (bread and cake)            0.381241
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.719689  0.224768    0.810600  1.126320  0.025208    1.479997
# 1            0.719689  0.221958    0.803599  1.116593  0.023177    1.427242
# 2            0.719689  0.395721    0.800262  1.111956  0.039843    1.403396
# 3            0.719689  0.201426    0.835125  1.160398  0.027843    1.700148
# 4            0.719689  0.314675    0.825397  1.146880  0.040300    1.605419
#
#    zhangs_metric
# 0       0.155183
# 1       0.144265
# 2       0.199172
# 3       0.182163
# 4       0.206978

# %% [markdown]
# Note that the rules above are not sorted by confidence. We should do that ourselves by using the `sort_values` function.

# %%
ap_rules.sort_values('confidence', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      antecedents       consequents  \
# 179  (frozen foods, biscuits, fruit, vegetables)  (bread and cake)
# 139                 (fruit, biscuits, margarine)  (bread and cake)
# 132              (fruit, biscuits, frozen foods)  (bread and cake)
# 138           (biscuits, milk-cream, vegetables)  (bread and cake)
# 117             (fruit, margarine, baking needs)  (bread and cake)
# ..                                           ...               ...
# 153   (bread and cake, frozen foods, vegetables)           (fruit)
# 152        (bread and cake, fruit, frozen foods)      (vegetables)
# 91                  (breakfast food, vegetables)           (fruit)
# 173       (milk-cream, vegetables, frozen foods)           (fruit)
# 2                                    (margarine)  (bread and cake)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 179            0.224552            0.719689  0.200778    0.894129  1.242383
# 139            0.231900            0.719689  0.202723    0.874185  1.214670
# 132            0.282905            0.719689  0.247028    0.873186  1.213282
# 138            0.267128            0.719689  0.232332    0.869741  1.208496
# 117            0.244003            0.719689  0.212016    0.868911  1.207342
# ..                  ...                 ...       ...         ...       ...
# 153            0.334558            0.640156  0.268424    0.802326  1.253329
# 152            0.334558            0.639939  0.268424    0.802326  1.253752
# 91             0.275989            0.640156  0.221310    0.801879  1.252632
# 173            0.285066            0.640156  0.228442    0.801365  1.251828
# 2              0.494489            0.719689  0.395721    0.800262  1.111956
#
#      leverage  conviction  zhangs_metric
# 179  0.039171    2.647667       0.251590
# 139  0.035828    2.227955       0.230089
# 132  0.043425    2.210406       0.245141
# 138  0.040083    2.151954       0.235410
# 117  0.036410    2.138320       0.227163
# ..        ...         ...            ...
# 153  0.054255    1.820389       0.303745
# 152  0.054328    1.821483       0.304150
# 91   0.044634    1.816290       0.278561
# 173  0.045955    1.811583       0.281380
# 2    0.039843    1.403396       0.199172
#
# [180 rows x 10 columns]

# %% [markdown]
# Now describe the first three that you see above in your own words.

# %% [markdown]
# ## 4 Boost fruit sales
# The supermarket manager wishes to boost the sale of fruit and therefore the manager needs to know other itemsets most likely be purchased with fruit to make promotion decisions.
#   - Using the same minimum support and minimum confidence value.
#   - List the top three itemsets to report to the supermarket manager.

# %%
# choose all the rules wihch have "fruit" (not canned fruit) as the consquent
fruit_rules = ap_rules[ap_rules.consequents == frozenset(['fruit'])]

fruit_rules.sort_values('confidence',  # sort based on 'confidence'
                        ascending=False).head(3) # choose the top 3 only
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            antecedents consequents  \
# 177  (bread and cake, frozen foods, biscuits, veget...     (fruit)
# 172                 (biscuits, milk-cream, vegetables)     (fruit)
# 140             (bread and cake, biscuits, vegetables)     (fruit)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 177            0.242057            0.640156  0.200778    0.829464  1.295723
# 172            0.267128            0.640156  0.219365    0.821197  1.282809
# 140            0.321375            0.640156  0.262805    0.817754  1.277430
#
#      leverage  conviction  zhangs_metric
# 177  0.045824    2.110082       0.301118
# 172  0.048361    2.012523       0.300817
# 140  0.057076    1.974497       0.320027

# %% [markdown]
# ## 5 FP-Growth
# Repeat task 3, but using the FP Growth algorithm instead.
#   - Compare the rules found.
#   - Are they consistent?

# %% [markdown]
# Import the `fpgrowth` function from our `mlxtend` module

# %%
from mlxtend.frequent_patterns import fpgrowth
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fp_itemsets = fpgrowth(df,
                       min_support=0.2, # choose the minimum support
                       use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fp_rules = association_rules(fp_itemsets,
                             metric='confidence',
                             min_threshold=0.8) # choose the minimum confidence
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# There are a lot of rules, lets compare just the first 10 most confident rules.

# %%
# Select the top 10 confident rules from each of our algorithms
fp_top_10 = fp_rules.sort_values('confidence', ascending=False).head(10)
ap_top_10 = ap_rules.sort_values('confidence', ascending=False).head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print("FP-Growth rules")
fp_top_10
# Out:
# FP-Growth rules
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      antecedents       consequents  \
# 46   (frozen foods, biscuits, fruit, vegetables)  (bread and cake)
# 101                 (fruit, biscuits, margarine)  (bread and cake)
# 31               (fruit, biscuits, frozen foods)  (bread and cake)
# 49            (biscuits, milk-cream, vegetables)  (bread and cake)
# 93              (fruit, margarine, baking needs)  (bread and cake)
# 42          (frozen foods, biscuits, vegetables)  (bread and cake)
# 94                (fruit, margarine, milk-cream)  (bread and cake)
# 34          (frozen foods, biscuits, milk-cream)  (bread and cake)
# 41                 (fruit, biscuits, vegetables)  (bread and cake)
# 88         (margarine, milk-cream, baking needs)  (bread and cake)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 46             0.224552            0.719689  0.200778    0.894129  1.242383
# 101            0.231900            0.719689  0.202723    0.874185  1.214670
# 31             0.282905            0.719689  0.247028    0.873186  1.213282
# 49             0.267128            0.719689  0.232332    0.869741  1.208496
# 93             0.244003            0.719689  0.212016    0.868911  1.207342
# 42             0.278798            0.719689  0.242057    0.868217  1.206378
# 94             0.237087            0.719689  0.205749    0.867821  1.205829
# 34             0.271234            0.719689  0.235358    0.867729  1.205700
# 41             0.303436            0.719689  0.262805    0.866097  1.203432
# 88             0.246812            0.719689  0.213313    0.864273  1.200899
#
#      leverage  conviction  zhangs_metric
# 46   0.039171    2.647667       0.251590
# 101  0.035828    2.227955       0.230089
# 31   0.043425    2.210406       0.245141
# 49   0.040083    2.151954       0.235410
# 93   0.036410    2.138320       0.227163
# 42   0.041409    2.127067       0.237205
# 94   0.035120    2.120699       0.223741
# 34   0.040154    2.119220       0.234103
# 41   0.044426    2.093388       0.242682
# 88   0.035685    2.065261       0.222110

# %%
print("Apriori rules")
ap_top_10
# Out:
# Apriori rules
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                      antecedents       consequents  \
# 179  (frozen foods, biscuits, fruit, vegetables)  (bread and cake)
# 139                 (fruit, biscuits, margarine)  (bread and cake)
# 132              (fruit, biscuits, frozen foods)  (bread and cake)
# 138           (biscuits, milk-cream, vegetables)  (bread and cake)
# 117             (fruit, margarine, baking needs)  (bread and cake)
# 133         (frozen foods, biscuits, vegetables)  (bread and cake)
# 163               (fruit, margarine, milk-cream)  (bread and cake)
# 130         (frozen foods, biscuits, milk-cream)  (bread and cake)
# 141                (fruit, biscuits, vegetables)  (bread and cake)
# 114        (margarine, milk-cream, baking needs)  (bread and cake)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 179            0.224552            0.719689  0.200778    0.894129  1.242383
# 139            0.231900            0.719689  0.202723    0.874185  1.214670
# 132            0.282905            0.719689  0.247028    0.873186  1.213282
# 138            0.267128            0.719689  0.232332    0.869741  1.208496
# 117            0.244003            0.719689  0.212016    0.868911  1.207342
# 133            0.278798            0.719689  0.242057    0.868217  1.206378
# 163            0.237087            0.719689  0.205749    0.867821  1.205829
# 130            0.271234            0.719689  0.235358    0.867729  1.205700
# 141            0.303436            0.719689  0.262805    0.866097  1.203432
# 114            0.246812            0.719689  0.213313    0.864273  1.200899
#
#      leverage  conviction  zhangs_metric
# 179  0.039171    2.647667       0.251590
# 139  0.035828    2.227955       0.230089
# 132  0.043425    2.210406       0.245141
# 138  0.040083    2.151954       0.235410
# 117  0.036410    2.138320       0.227163
# 133  0.041409    2.127067       0.237205
# 163  0.035120    2.120699       0.223741
# 130  0.040154    2.119220       0.234103
# 141  0.044426    2.093388       0.242682
# 114  0.035685    2.065261       0.222110

# %% [markdown]
# Do the above tables agree?
